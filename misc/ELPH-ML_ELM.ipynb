# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.append("incl/")

import ELPH_utils
import ELPH_Scaler
import ELPH_Optimizer

from ELPH_ELM import SVDELM
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
runs = ELPH_utils.load_runs(filename='../runs_rand_inits.npz')

# runs = runs[::5]
# for k in range(len(runs)):
#     runs[k] = runs[k][:,::2]

n_runs = len(runs)
n_kmax = runs[0].shape[0]

print(n_runs, 'loaded with n_kmax =', n_kmax)
# Out:
# 500 loaded with n_kmax = 80

# %%
optimizer = ELPH_Optimizer.ridge(alpha=10.**-3.43)

# scaler = ELPH_Scaler.standardize_scaler()
scaler = ELPH_Scaler.normalize_scaler(0.63)
# scaler = ELPH_Scaler.tanh_scaler(arg_scale=1.0, out_scale=0.3)

ELM = SVDELM(runs)
ELM.train(rdim=20, prdim = 30, n_VAR_steps=2, ELM_nodes=500, intercept=True, optimizer=optimizer, scaler=scaler)
ELM.print_status()
# Out:
# 0.0 1.0 1000 None None 500
# 0.0 1.0 500
# rdim:  20
# n_VAR_steps:  2
# ELM_nodes:  500
# ELM_weights_mean:  0.0
# ELM_weights_std:  1.0
# VAR state shape:  (40, 199500)
# ELM state shape:  (541, 199500)
# target shape:  (30, 199500)
# weights shape:  (541, 30)

# %%
plt.imshow(ELM.w, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('ELM weights')
plt.show()

plt.semilogy(np.sort(np.ravel(np.abs(ELM.w))))
plt.title('sorted ELM weights')
plt.show()

plt.hist(np.ravel(ELM.w), bins=200)
plt.title('ELM weights')
plt.xlabel('weight')
plt.ylabel('count')
plt.show()

plt.hist(np.ravel(ELM.coef_matrix), bins=200)
plt.title('coefficient matrix elements')
plt.show()

plt.hist(np.ravel(ELM.coef_matrix[:ELM.rdim]), bins=200)
plt.title('reduced coefficient matrix elements')
plt.show()

# %%
plt.semilogy(ELM.S, 'o')
plt.title('singular values off all runs')
plt.show()
 
for l in range(ELM.rdim):
  plt.plot(ELM.U[:,l],  label='U_'+str(l))
plt.title('first ' + str(ELM.rdim) + ' modes')
plt.show()

# %%
optimizer = ELPH_Optimizer.ridge(alpha=10.**-2)
scaler = ELPH_Scaler.normalize_scaler(1.0)

train_kwargs = {'rdim':20, 'prdim':30, 'n_VAR_steps':2, 'ELM_nodes':1000,  'ELM_weights_mean':0.0, 'ELM_weights_std':1.0, 'intercept':True, 'full_hist':False, 'optimizer':optimizer, 'scaler':scaler}
score_kwargs = {'norm':'max', 'errSVD':False}

m,s = ELPH_utils.get_KFold_CV_scores(ELM, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
print(m)
print(np.std(s))
print(s)
# Out:
# 0.07602393094327604
# 0.10097041320953817
# [0.27704927108514865, 0.01844950669850547, 0.04400173693587429, 0.01752397560779465, 0.02309516438905713]

# %%
def elm_error(elm_std):
    optimizer = ELPH_Optimizer.ridge(alpha=10.**-3.43)
    scaler = ELPH_Scaler.normalize_scaler(0.63)

    train_kwargs = {'rdim':20, 'prdim':30, 'n_VAR_steps':2, 'ELM_nodes':1000,  'ELM_weights_mean':0.0, 'ELM_weights_std':elm_std, 'intercept':True, 'full_hist':False, 'optimizer':optimizer, 'scaler':scaler}
    score_kwargs = {'norm':'max', 'errSVD':False}

    m,s = ELPH_utils.get_KFold_CV_scores(ELM, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
    return -np.sum(s)

from bayes_opt import BayesianOptimization

# Bounded region of parameter space
pbounds = {'elm_std': (0.01, 5)}

optimizer = BayesianOptimization(
    f=elm_error,
    pbounds=pbounds,
    random_state=1,
)


optimizer.maximize(
    init_points=10,
    n_iter=90,
)
# Out:
# |   iter    |  target   |  elm_std  |
# -------------------------------------
# |  1        | -0.9199   |  2.091    |
# |  2        | -4.995    |  3.604    |
# |  3        | -0.3244   |  0.01057  |
# |  4        | -0.1911   |  1.519    |
# |  5        | -0.0626   |  0.7423   |
# |  6        | -0.0792   |  0.4708   |
# |  7        | -0.07251  |  0.9394   |
# |  8        | -0.5774   |  1.734    |
# |  9        | -0.9377   |  1.99     |
# |  10       | -2.181    |  2.699    |
# |  11       | -7.212    |  5.0      |
# |  12       | -0.07658  |  1.232    |
# |  13       | -1.053    |  0.2595   |
# |  14       | -0.631    |  1.734    |
# |  15       | -0.3761   |  1.731    |
# |  16       | -0.06228  |  0.746    |
# |  17       | -0.06072  |  0.9353   |
# |  18       | -0.1402   |  1.236    |
# |  19       | -0.07524  |  0.4752   |
# |  20       | -0.2339   |  1.514    |
# |  21       | -0.09559  |  1.227    |
# |  22       | -0.09205  |  1.222    |
# |  23       | -0.07233  |  1.217    |
# |  24       | -0.07295  |  1.212    |
# |  25       | -0.09085  |  1.206    |
# |  26       | -0.09881  |  1.202    |
# |  27       | -0.05951  |  0.9302   |
# |  28       | -0.06258  |  0.9247   |
# |  29       | -0.06482  |  0.9199   |
# |  30       | -0.06175  |  0.9153   |
# |  31       | -0.06141  |  0.9104   |
# |  32       | -0.07248  |  0.9054   |
# |  33       | -0.06313  |  0.9007   |
# |  34       | -0.06273  |  0.8958   |
# |  35       | -0.05933  |  0.8911   |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/bayes_opt/target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.8862195404080134,)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2935/1618563077.py in <module>
#      21
#      22
# ---> 23 optimizer.maximize(
#      24     init_points=10,
#      25     n_iter=90,
#
# ~/.local/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# ~/.local/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# ~/.local/lib/python3.9/site-packages/bayes_opt/target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# /tmp/ipykernel_2935/1618563077.py in elm_error(elm_std)
#       6     score_kwargs = {'norm':'max', 'errSVD':False}
#       7
# ----> 8     m,s = ELPH_utils.get_KFold_CV_scores(ELM, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
#       9     return -np.sum(s)
#      10
#
# ~/Arbeit/Projekt_Malte_Stefan/ELPH-ML/incl/ELPH_utils.py in get_KFold_CV_scores(model, runs, folds, seed, score_kwargs, train_kwargs)
#      73         #train the model on the training runs and get scores from the testing runs
#      74         model.load_runs(train_runs)
# ---> 75         model.train(**train_kwargs)
#      76         mean_score = model.score_multiple_runs(test_runs, **score_kwargs)[0]
#      77
#
# ~/Arbeit/Projekt_Malte_Stefan/ELPH-ML/incl/ELPH_ELM.py in train(self, rdim, prdim, n_VAR_steps, ELM_nodes, ELM_weights_mean, ELM_weights_std, intercept, full_hist, scaler, optimizer, column_weights, **kwargs)
#     176         self.VAR_state, self.target = self.__build_VAR_training_matrices()
#     177
# --> 178         self.ELM_state = self.__build_ELM_training_matrices()
#     179
#     180         #add bias/intercept
#
# ~/Arbeit/Projekt_Malte_Stefan/ELPH-ML/incl/ELPH_ELM.py in __build_ELM_training_matrices(self)
#     108         self.projection_matrix = np.random.uniform(self.ELM_weights_mean, self.ELM_weights_std, (np.shape(self.VAR_state)[0], self.ELM_nodes))
#     109         self.bias_matrix = np.random.uniform(self.ELM_weights_mean, self.ELM_weights_std, self.ELM_nodes)
# --> 110         projected_data = np.tanh(self.VAR_state.T @ self.projection_matrix + self.bias_matrix)
#     111         state = np.concatenate([projected_data.T, self.VAR_state])
#     112
#
# KeyboardInterrupt:

# %%
optimizer = ELPH_Optimizer.ridge(alpha=10.**-3.43)
scaler = ELPH_Scaler.normalize_scaler(1.0)

train_kwargs = {'rdim':20, 'prdim':30, 'n_VAR_steps':2, 'ELM_nodes':1000,  'ELM_weights_mean':0.0, 'ELM_weights_std':1.0, 'intercept':True, 'full_hist':False, 'optimizer':optimizer, 'scaler':scaler}
score_kwargs = {'norm':'max', 'errSVD':False}

m,s = ELPH_utils.get_KFold_CV_scores(ELM, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
print(m)
print(np.std(s))
print(s)
# Out:
# 0.035555279221701076
# 0.0165254354807637
# [0.011814595872674407, 0.02040061798817875, 0.0420381388256398, 0.0502036022210863, 0.0533194412009261]

# %%
optimizer = ELPH_Optimizer.ridge(alpha=10.**-5)
scaler = ELPH_Scaler.normalize_scaler(1.0)

train_kwargs = {'rdim':20, 'prdim':30, 'n_VAR_steps':2, 'ELM_nodes':1000,  'ELM_weights_mean':0.0, 'ELM_weights_std':1.0, 'intercept':True, 'full_hist':False, 'optimizer':optimizer, 'scaler':scaler}
score_kwargs = {'norm':'max', 'errSVD':False}

m,s = ELPH_utils.get_KFold_CV_scores(ELM, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
print(m)
print(np.std(s))
print(s)
# Out:
# 0.6322630525901223
# 0.31430198424130174
# [0.33370302089649617, 0.30326153785292354, 0.582368040244036, 0.7912896479382167, 1.1506930160189393]
