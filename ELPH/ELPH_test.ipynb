# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [9, 6]

import ELPH

# %%
system = ELPH.ELPH(kmax=2.0, n_kmax=80)

# %%
inits = system.get_init_cond_gauss(max_pos = 0.2, width = 0.0125, density=0.025)

plt.plot(system.E_el_vec,inits[:system.n_kmax])
plt.show()

# %%
trajectory = system.get_full_trajectory(inits, tmax=2000, n_tmax=1001)

# %%
plt.imshow(trajectory[:,:system.n_kmax], aspect='auto', interpolation='none', origin='lower',cmap='Reds')
plt.colorbar()
plt.show()

# %%
el_trajectory = system.get_electron_trajectory(inits, tmax=2000, n_tmax=1001)

plt.imshow(el_trajectory, aspect='auto', interpolation='none', origin='lower',cmap='Reds')
plt.colorbar()
plt.show()
