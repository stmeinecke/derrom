# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.append("incl/")

import ELPH_dyn
import ELPH_utils


#global hyperparameters
kmax = 4.
n_kmax = 30


# init = ELPH_dyn.get_init_cond_gauss(kmax = kmax, n_kmax = n_kmax, max_pos = 0.15, width = 0.05, density=density)
# plt.plot(init[:n_kmax])
# plt.show()

# nkdyn = ELPH_dyn.get_el_dynamics(init, n_kmax = n_kmax)
# plt.imshow(nkdyn, aspect='auto')
# plt.colorbar()
# plt.show()

# %%
n_runs = 100

paras = np.zeros((n_runs,3))

paras[:,0] = np.linspace(0.1,0.7,n_runs) #max_pos
paras[:,1] = 0.05 #width
paras[:,2] = 0.1 #density

runs = ELPH_utils.get_runs_gaussian_init(kmax, n_kmax, paras, tmax=5000, n_tmax=1000)
# Out:
# run  0  from  30
# /Users/Stefan/Code/ELPH-ML/incl/ELPH_dyn.py:105: RuntimeWarning: invalid value encountered in sqrt
#   helper1 = np.sqrt(x*x+get_k(dk,n_k)*get_k(dk,n_k) - 2.*x*get_k(dk,n_k)*np.cos(phi_diff))
# run  1  from  30
# run  2  from  30
# run  3  from  30
# run  4  from  30
# run  5  from  30
# run  6  from  30
# run  7  from  30
# run  8  from  30
# run  9  from  30
# run  10  from  30
# run  11  from  30
# run  12  from  30
# run  13  from  30
# run  14  from  30
# run  15  from  30
# run  16  from  30
# run  17  from  30
# run  18  from  30
# run  19  from  30
# run  20  from  30
# run  21  from  30
# run  22  from  30
# run  23  from  30
# run  24  from  30
# run  25  from  30
# run  26  from  30
# run  27  from  30
# run  28  from  30
# run  29  from  30

# %%
# plt.imshow(runs[1], aspect='auto')
# plt.colorbar()
# plt.show()

print('runs[0] shape: ', runs[0].shape)

for k in range(n_runs):
    plt.plot(runs[k][:,0])

plt.title('initial conditions')
plt.show()
# Out:
# runs[0] shape:  (30, 1000)

# %%
import ELPH_VAR
    
model = ELPH_VAR.SVDVAR(runs, rdim=10, n_VAR_steps=5)

model.train(alpha=1e-5, rdim = 10, n_VAR_steps = 5, method='ridge')

model.print_status()
# Out:
# rdim:  10
# n_VAR_steps:  5
# state shape:  (50, 29850)
# target shape:  (10, 29850)
# weights shape:  (50, 10)

# %%
plt.semilogy(model.S)
plt.title('singular values off all runs')
plt.show()

rdim = 5 

for l in range(rdim):
  plt.plot(model.U[:,l], label='Uhat_'+str(l))
plt.title('first ' + str(rdim) + ' modes')
plt.show()

# %%
run = runs[1]
testpred = model.predict_single_run(run)

print(model.get_error(run, norm='fro') )

plt.imshow(run, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('truth')
plt.show()

plt.imshow(testpred, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('prediction')
plt.show()

plt.imshow(run-testpred, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('prediction')
plt.xlim(0,20)
plt.show()
# Out:
# 1.3983099044157337

# %%
mean_score, scores = ELPH_utils.get_KFold_CV_scores(model, runs, folds=5, seed=817, alpha=1e-6, rdim=6, n_VAR_steps=5, norm='fro')

print('mean score: ', mean_score)
print('scores: ', scores)
# Out:
# mean score:  1.7885815330679455
# scores:  [1.913733119955688, 1.4173651991251897, 2.607781460313195, 1.2057138563121201, 1.798314029633536]
