# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.append("incl/")

import ELPH_dyn
import ELPH_utils


#global hyperparameters
kmax = 4.
n_kmax = 80


# init = ELPH_dyn.get_init_cond_gauss(kmax = kmax, n_kmax = n_kmax, max_pos = 0.15, width = 0.05, density=density)
# plt.plot(init[:n_kmax])
# plt.show()

# nkdyn = ELPH_dyn.get_el_dynamics(init, n_kmax = n_kmax)
# plt.imshow(nkdyn, aspect='auto')
# plt.colorbar()
# plt.show()

# %%
n_runs = 100

paras = np.zeros((n_runs,3))

paras[:,0] = np.linspace(0.1,0.7,n_runs) #max_pos
paras[:,1] = 0.05 #width
paras[:,2] = 0.1 #density

runs = ELPH_utils.get_runs_gaussian_init(kmax, n_kmax, paras, tmax=5000, n_tmax=1000)
# Out:
# run  1  from  100
# incl/ELPH_dyn.py:105: RuntimeWarning: invalid value encountered in sqrt
#   helper1 = np.sqrt(x*x+get_k(dk,n_k)*get_k(dk,n_k) - 2.*x*get_k(dk,n_k)*np.cos(phi_diff))
# run  2  from  100
# run  3  from  100
# run  4  from  100
# run  5  from  100
# run  6  from  100
# run  7  from  100
# run  8  from  100
# run  9  from  100
# run  10  from  100
# run  11  from  100
# run  12  from  100
# run  13  from  100
# run  14  from  100
# run  15  from  100
# run  16  from  100
# run  17  from  100
# run  18  from  100
# run  19  from  100
# run  20  from  100
# run  21  from  100
# run  22  from  100
# run  23  from  100
# run  24  from  100
# run  25  from  100
# run  26  from  100
# run  27  from  100
# run  28  from  100
# run  29  from  100
# run  30  from  100
# run  31  from  100
# run  32  from  100
# run  33  from  100
# run  34  from  100
# run  35  from  100
# run  36  from  100
# run  37  from  100
# run  38  from  100
# run  39  from  100
# run  40  from  100
# run  41  from  100
# run  42  from  100
# run  43  from  100
# run  44  from  100
# run  45  from  100
# run  46  from  100
# run  47  from  100
# run  48  from  100
# run  49  from  100
# run  50  from  100
# run  51  from  100
# run  52  from  100
# run  53  from  100
# run  54  from  100
# run  55  from  100
# run  56  from  100
# run  57  from  100
# run  58  from  100
# run  59  from  100
# run  60  from  100
# run  61  from  100
# run  62  from  100
# run  63  from  100
# run  64  from  100
# run  65  from  100
# run  66  from  100
# run  67  from  100
# run  68  from  100
# run  69  from  100
# run  70  from  100
# run  71  from  100
# run  72  from  100
# run  73  from  100
# run  74  from  100
# run  75  from  100
# run  76  from  100
# run  77  from  100
# run  78  from  100
# run  79  from  100
# run  80  from  100
# run  81  from  100
# run  82  from  100
# run  83  from  100
# run  84  from  100
# run  85  from  100
# run  86  from  100
# run  87  from  100
# run  88  from  100
# run  89  from  100
# run  90  from  100
# run  91  from  100
# run  92  from  100
# run  93  from  100
# run  94  from  100
# run  95  from  100
# run  96  from  100
# run  97  from  100
# run  98  from  100
# run  99  from  100
# run  100  from  100

# %%
# plt.imshow(runs[1], aspect='auto')
# plt.colorbar()
# plt.show()

print('runs[0] shape: ', runs[0].shape)

for k in range(n_runs):
    plt.plot(runs[k][:,0])

plt.title('initial conditions')
plt.show()
# Out:
# runs[0] shape:  (80, 1000)

# %%
import ELPH_VAR
    
model = ELPH_VAR.SVDVAR(runs, rdim=10, n_VAR_steps=5)

model.train(alpha=1e-5, rdim = 20, n_VAR_steps = 20, method='ridge')

model.print_status()
# Out:
# rdim:  20
# n_VAR_steps:  5
# state shape:  (100, 99500)
# target shape:  (20, 99500)
# weights shape:  (100, 20)

# %%
plt.semilogy(model.S)
plt.title('singular values off all runs')
plt.show()
 
for l in range(model.rdim):
  plt.plot(model.U[:,l], label='Uhat_'+str(l))
plt.title('first ' + str(rdim) + ' modes')
plt.show()

# %%
run = runs[1]
testpred = model.predict_single_run(run)

print(model.get_error(run, norm='fro') )

plt.imshow(run, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('truth')
plt.show()

plt.imshow(testpred, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('prediction')
plt.show()

plt.imshow(run-testpred, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('prediction')
plt.xlim(0,20)
plt.show()
# Out:
# 1.0032341717636046

# %%
mean_score, scores = ELPH_utils.get_KFold_CV_scores(model, runs, folds=5, seed=817, alpha=1e-4, rdim=16, n_VAR_steps=11, norm='fro')

print('mean score: ', mean_score)
print('scores: ', scores)
# Out:
# mean score:  0.3384241464645593
# scores:  [0.3882885555489126, 0.34120534010536907, 0.38296088169470066, 0.3131801506123099, 0.26648580436150426]

# %%
def get_BO_score(aExp, rdim, n_VAR_steps):
    alpha = 10.0**aExp
    rdim = int(rdim)
    n_VAR_steps = int(n_VAR_steps)
    
    m,s = ELPH_utils.get_KFold_CV_scores(model, runs, folds=5, seed=817, alpha=alpha, rdim=rdim, n_VAR_steps=n_VAR_steps, norm='fro')
    return -1.*m - 1.*np.std(s)


# print(KFCV_score(-6,3,5))

from bayes_opt import BayesianOptimization

# Bounded region of parameter space
pbounds = {'aExp': [-7, -1], 'rdim': [1,20], 'n_VAR_steps': [1,20]}

optimizer = BayesianOptimization(
    f=get_BO_score,
    pbounds=pbounds,
    random_state=816,
)

optimizer.maximize(init_points=10, n_iter=100)
# Out:
# |   iter    |  target   |   aExp    | n_VAR_... |   rdim    |
# -------------------------------------------------------------
# |  1        | -1.341    | -5.431    |  4.508    |  17.45    |
# |  2        | -0.5117   | -5.107    |  19.35    |  16.8     |
# |  3        | -4.719    | -5.243    |  1.752    |  9.181    |
# |  4        | -3.82     | -6.192    |  2.227    |  8.044    |
# |  5        | -1.77     | -5.33     |  16.53    |  15.72    |
# |  6        | -4.398    | -4.921    |  8.437    |  4.38     |
# |  7        | -1.262e+0 | -6.306    |  12.92    |  3.167    |
# |  8        | -0.8235   | -3.567    |  6.867    |  14.92    |
# |  9        | -482.1    | -5.932    |  9.547    |  8.022    |
# |  10       | -3.152e+0 | -6.727    |  4.886    |  16.03    |
# |  11       | -3.91     | -1.339    |  5.911    |  6.908    |
# |  12       | -8.291    | -4.192    |  3.317    |  1.597    |
# |  13       | -0.5977   | -1.336    |  12.08    |  20.0     |
# |  14       | -1.566e+1 | -7.0      |  10.66    |  20.0     |
# |  15       | -1.058    | -1.064    |  15.64    |  11.19    |
# |  16       | -4.7      | -1.0      |  1.0      |  15.36    |
# |  17       | -2.23e+77 | -6.782    |  19.89    |  9.508    |
# |  65       | -0.436    | -2.809    |  17.31    |  14.49    |
# |  66       | -4.584    | -5.672    |  16.92    |  12.41    |
# |  67       | -6.865e+1 | -6.993    |  5.433    |  4.63     |
# |  68       | -1.069e+3 | -6.974    |  7.308    |  19.66    |
# |  69       | -5.274    | -6.104    |  1.0      |  4.496    |
# |  70       | -8.106    | -4.506    |  9.928    |  1.095    |
# |  71       | -4.007    | -4.291    |  19.79    |  3.338    |
# |  72       | -10.2     | -1.0      |  1.0      |  1.0      |
# |  73       | -1.01     | -3.509    |  19.76    |  10.59    |
# |  74       | -0.2055   | -2.762    |  20.0     |  20.0     |
# |  75       | -6.001    | -3.01     |  11.99    |  3.628    |
# |  76       | -8.128    | -1.0      |  20.0     |  1.0      |
# |  77       | -4.694    | -2.299    |  1.085    |  11.51    |
# |  78       | -2.363    | -1.05     |  15.76    |  7.166    |
# |  79       | -0.5094   | -2.28     |  12.99    |  17.41    |
# |  80       | -1.62     | -2.829    |  3.517    |  19.9     |
# |  81       | -3.951    | -6.967    |  2.633    |  11.74    |
# |  82       | -4.172e+6 | -6.99     |  12.96    |  12.35    |
# |  83       | -1.308    | -1.163    |  11.91    |  13.19    |
# |  84       | -1.151    | -1.026    |  8.983    |  19.65    |
# |  85       | -1.246e+0 | -6.863    |  7.387    |  13.91    |
# |  86       | -8.237    | -3.64     |  6.712    |  1.282    |
# |  87       | -4.631    | -1.161    |  4.796    |  15.47    |
# |  88       | -9.884e+0 | -6.855    |  10.57    |  5.027    |
# |  89       | -1.567e+1 | -6.971    |  11.46    |  1.181    |
# |  90       | -8.339    | -6.929    |  3.805    |  1.219    |
# |  91       | -465.4    | -6.808    |  4.143    |  19.97    |
# |  92       | -5.493    | -1.049    |  3.891    |  4.154    |
# |  93       | -2.247    | -1.038    |  7.736    |  15.57    |
# |  94       | -2.716e+2 | -6.897    |  11.49    |  9.525    |
# |  95       | -7.155e+5 | -6.912    |  19.92    |  4.381    |
# |  96       | -4.867    | -3.293    |  1.097    |  6.779    |
# |  97       | -8.106    | -4.506    |  13.59    |  1.016    |
# |  98       | -0.3633   | -3.507    |  15.15    |  15.89    |
# |  99       | -6.973    | -1.005    |  14.38    |  3.481    |
# |  100      | -1.249e+6 | -6.956    |  14.39    |  6.151    |
# |  101      | -0.4066   | -4.041    |  19.84    |  13.97    |
# |  102      | -0.5224   | -1.035    |  15.07    |  18.96    |
# |  103      | -8.119    | -3.488    |  18.45    |  1.203    |
# |  104      | -2.039    | -1.024    |  12.36    |  9.617    |
# |  105      | -4.789    | -6.997    |  1.477    |  17.15    |
# |  106      | -3.111    | -1.21     |  6.273    |  9.401    |
# |  107      | -0.363    | -4.337    |  12.29    |  16.12    |
# |  108      | -1.209e+1 | -6.956    |  7.125    |  7.001    |
# |  109      | -3.179e+0 | -6.945    |  7.943    |  16.95    |
# |  110      | -0.3356   | -3.521    |  10.67    |  19.98    |
# =============================================================
