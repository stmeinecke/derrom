# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.append("incl/")

import ELPH_dyn
import ELPH_utils


#global hyperparameters
kmax = 4.
n_kmax = 80


# init = ELPH_dyn.get_init_cond_gauss(kmax = kmax, n_kmax = n_kmax, max_pos = 0.15, width = 0.05, density=density)
# plt.plot(init[:n_kmax])
# plt.show()

# nkdyn = ELPH_dyn.get_el_dynamics(init, n_kmax = n_kmax)
# plt.imshow(nkdyn, aspect='auto')
# plt.colorbar()
# plt.show()

# %%
n_runs = 100

paras = np.zeros((n_runs,3))

paras[:,0] = np.linspace(0.1,0.7,n_runs) #max_pos
paras[:,1] = 0.05 #width
paras[:,2] = 0.1 #density

runs = ELPH_utils.get_runs_gaussian_init(kmax, n_kmax, paras, tmax=2000, n_tmax=400)
# Out:
# run  1  from  100
# run  2  from  100
# run  3  from  100
# run  4  from  100
# run  5  from  100
# run  6  from  100
# run  7  from  100
# run  8  from  100
# run  9  from  100
# run  10  from  100
# run  11  from  100
# run  12  from  100
# run  13  from  100
# run  14  from  100
# run  15  from  100
# run  16  from  100
# run  17  from  100
# run  18  from  100
# run  19  from  100
# run  20  from  100
# run  21  from  100
# run  22  from  100
# run  23  from  100
# run  24  from  100
# run  25  from  100
# run  26  from  100
# run  27  from  100
# run  28  from  100
# run  29  from  100
# run  30  from  100
# run  31  from  100
# run  32  from  100
# run  33  from  100
# run  34  from  100
# run  35  from  100
# run  36  from  100
# run  37  from  100
# run  38  from  100
# run  39  from  100
# run  40  from  100
# run  41  from  100
# run  42  from  100
# run  43  from  100
# run  44  from  100
# run  45  from  100
# run  46  from  100
# run  47  from  100
# run  48  from  100
# run  49  from  100
# run  50  from  100
# run  51  from  100
# run  52  from  100
# run  53  from  100
# run  54  from  100
# run  55  from  100
# run  56  from  100
# run  57  from  100
# run  58  from  100
# run  59  from  100
# run  60  from  100
# run  61  from  100
# run  62  from  100
# run  63  from  100
# run  64  from  100
# run  65  from  100
# run  66  from  100
# run  67  from  100
# run  68  from  100
# run  69  from  100
# run  70  from  100
# run  71  from  100
# run  72  from  100
# run  73  from  100
# run  74  from  100
# run  75  from  100
# run  76  from  100
# run  77  from  100
# run  78  from  100
# run  79  from  100
# run  80  from  100
# run  81  from  100
# run  82  from  100
# run  83  from  100
# run  84  from  100
# run  85  from  100
# run  86  from  100
# run  87  from  100
# run  88  from  100
# run  89  from  100
# run  90  from  100
# run  91  from  100
# run  92  from  100
# run  93  from  100
# run  94  from  100
# run  95  from  100
# run  96  from  100
# run  97  from  100
# run  98  from  100
# run  99  from  100
# run  100  from  100

# %%
# plt.imshow(runs[1], aspect='auto')
# plt.colorbar()
# plt.show()

print('runs[0] shape: ', runs[0].shape)

for k in range(n_runs):
    plt.plot(runs[k][:,500])

plt.title('initial conditions')
plt.show()
# Out:
# runs[0] shape:  (80, 600)

# %%
from ELPH_VAR import SVDVAR
    
VAR = SVDVAR(runs, rdim=10, n_VAR_steps=5)

VAR.train(alpha=10**-2.7, rdim = 20, n_VAR_steps = 20, method='ridge')

VAR.print_status()
# Out:
# rdim:  20
# n_VAR_steps:  20
# state shape:  (400, 58000)
# target shape:  (20, 58000)
# weights shape:  (400, 20)

# %%
plt.semilogy(VAR.S, 'o')
plt.title('singular values off all runs')
plt.show()
 
for l in range(VAR.rdim):
  plt.plot(VAR.U[:,l],  label='Uhat_'+str(l))
plt.title('first ' + str(VAR.rdim) + ' modes')
plt.show()

# %%
run = runs[80]
testpred = VAR.predict_single_run(run)

print(VAR.get_error(run, norm='fro') )

plt.imshow(run, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('truth')
plt.show()

plt.imshow(testpred, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('prediction')
plt.show()

plt.imshow(run-testpred, aspect='auto', interpolation='None')
plt.colorbar()
plt.title('diffrence: prediction - test')
plt.xlim(0,20)
plt.show()
# Out:
# 0.08477281502140938

# %%
train_kwargs = {'alpha':10**-2.7, 'rdim':20, 'n_VAR_steps':20}
score_kwargs = {'norm':'max', 'errSVD':False}

mean_score, scores = ELPH_utils.get_KFold_CV_scores(VAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)

print('mean score: ', mean_score)
print('scores: ', scores)
# Out:
# mean score:  0.00857749059841931
# scores:  [0.007781204726127228, 0.009120398395284448, 0.008459626345769142, 0.009107721286174814, 0.008418502238740928]

# %%
def get_BO_score(aExp, rdim, n_VAR_steps):
    alpha = 10.0**aExp
    rdim = int(rdim)
    n_VAR_steps = int(n_VAR_steps)
    
    train_kwargs = {'alpha':alpha, 'rdim':rdim, 'n_VAR_steps':n_VAR_steps}
    score_kwargs = {'norm':'fro', 'errSVD':False}
    
    m,s = ELPH_utils.get_KFold_CV_scores(VAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
    return -1.*m - 1.*np.std(s)


# print(KFCV_score(-6,3,5))

from bayes_opt import BayesianOptimization

# Bounded region of parameter space
pbounds = {'aExp': [-6, -1], 'rdim': [1,20], 'n_VAR_steps': [1,20]}

optimizer = BayesianOptimization(
    f=get_BO_score,
    pbounds=pbounds,
    random_state=816,
)

# optimizer.maximize(init_points=10, n_iter=100)

# %%
from ELPH_NVAR import SVDNVAR


ntestrun = 32
train_runs = runs.copy()
test_run = train_runs.pop(ntestrun)

a = 1e-2
r = 5
n = 3


NVAR = SVDNVAR(train_runs)

NVAR.train(alpha=a, rdim=r, n_VAR_steps=n, NVAR_p=2)

NVAR.print_status()

plt.imshow(NVAR.w, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('NVAR weights')
plt.show()

plt.semilogy(np.sort(np.ravel(np.abs(NVAR.w))))
plt.title('sorted NVAR weights')
plt.show()


print('NVAR err: ', NVAR.get_error(test_run, norm='fro') )
trNVAR = NVAR.predict_single_run(test_run)

plt.imshow(trNVAR, aspect='auto')
plt.colorbar()
plt.xlim(0,100)
plt.show()


VAR.load_runs(train_runs)
VAR.train(alpha=a, rdim=r, n_VAR_steps=n)

VAR.print_status()
print('VAR err: ', VAR.get_error(test_run, norm='fro') )
trVAR = VAR.predict_single_run(test_run)
# Out:
# rdim:  5
# n_VAR_steps:  3
# NVAR_p:  2
# VAR state shape:  (15, 59103)
# NVAR state shape:  (135, 59103)
# target shape:  (5, 59103)
# weights shape:  (135, 5)
# NVAR err:  3.5661410005626943
# rdim:  5
# n_VAR_steps:  3
# state shape:  (15, 59103)
# target shape:  (5, 59103)
# weights shape:  (15, 5)
# VAR err:  5.738859822058509

# %%
train_runs = runs[::1]
test_run = train_runs.pop(45)

NVAR.load_runs(train_runs)

NVAR.train(rdim=20, n_VAR_steps=2, NVAR_p=2, method='stlsq', alpha=1e-3, threshold=0, intercept=True, standardize=False)

NVAR.print_status()

masked_weights = np.ma.masked_values(NVAR.w,0.0)

plt.imshow(masked_weights, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('NVAR weights')
plt.show()

plt.semilogy(np.sort(np.ravel(np.abs(NVAR.w))))
plt.title('sorted NVAR weights')
plt.show()


print('NVAR err: ', NVAR.get_error(test_run, norm='fro') )
preNVAR = NVAR.predict_single_run(test_run)

plt.imshow(preNVAR, aspect='auto')
plt.colorbar()
plt.title('prediction')
# plt.xlim(0,100)
plt.show()

plt.imshow(preNVAR-test_run, aspect='auto')
plt.colorbar()
plt.title('difference')
# plt.xlim(0,100)
plt.show()
# Out:
# rdim:  20
# n_VAR_steps:  2
# NVAR_p:  2
# VAR state shape:  (40, 59202)
# NVAR state shape:  (861, 59202)
# target shape:  (20, 59202)
# weights shape:  (861, 20)
# NVAR err:  0.9267317036549243

# %%
def get_BayO_score(aExp, thrExp):
    alpha = 10.0**aExp
    threshold = 10**thrExp
    
    train_kwargs = {'alpha':alpha, 'threshold':threshold, 'rdim':20, 'n_VAR_steps':2, 'NVAR_p':2, 'method':'stlsq', 'intercept':True, 'standardize':False}
    score_kwargs = {'norm':'fro', 'errSVD':False}
    
    m,s = ELPH_utils.get_KFold_CV_scores(NVAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
    return -1.*m - 1.*np.std(s)

# print(get_BayO_score(-3,-5))

from bayes_opt import BayesianOptimization
# Bounded region of parameter space
pbounds = {'aExp': [-4, -1], 'thrExp': [-6,-3]}
optimizer = BayesianOptimization(f=get_BayO_score, pbounds=pbounds, random_state=817)

# optimizer.maximize(init_points=10, n_iter=100)

# %%
train_kwargs = {'alpha':10**-3.5, 'threshold':10**-3.0, 'rdim':20, 'n_VAR_steps':2, 'NVAR_p':2, 'method':'stlsq', 'intercept':True, 'standardize':False}
score_kwargs = {'norm':'fro', 'errSVD':False}

m,s = ELPH_utils.get_KFold_CV_scores(NVAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
print(m)
print(s)
# Out:
# /usr/local/lib/python3.9/site-packages/numpy/core/numeric.py:936: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# /Users/Stefan/Code/ELPH-ML/incl/ELPH_NVAR.py:142: RuntimeWarning: invalid value encountered in matmul
#   pred[:,j] = self.w.T @ NVAR_vec
# /usr/local/lib/python3.9/site-packages/numpy/core/numeric.py:936: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# /Users/Stefan/Code/ELPH-ML/incl/ELPH_NVAR.py:142: RuntimeWarning: invalid value encountered in matmul
#   pred[:,j] = self.w.T @ NVAR_vec
# /usr/local/lib/python3.9/site-packages/numpy/core/numeric.py:936: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# /Users/Stefan/Code/ELPH-ML/incl/ELPH_NVAR.py:142: RuntimeWarning: invalid value encountered in matmul
#   pred[:,j] = self.w.T @ NVAR_vec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [83], in <cell line: 4>()
#       1 train_kwargs = {'alpha':10**-3.5, 'threshold':10**-3.0, 'rdim':20, 'n_VAR_steps':2, 'NVAR_p':2, 'method':'stlsq', 'intercept':True, 'standardize':False}
#       2 score_kwargs = {'norm':'fro', 'errSVD':False}
# ----> 4 m,s = ELPH_utils.get_KFold_CV_scores(NVAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
#       5 print(m)
#       6 print(s)
#
# File ~/Code/ELPH-ML/incl/ELPH_utils.py:83, in get_KFold_CV_scores(model, runs, folds, seed, score_kwargs, train_kwargs)
#      81 #train the model on the training runs and get scores from the testing runs
#      82 model.load_runs(train_runs)
# ---> 83 model.train(**train_kwargs)
#      84 mean_score = model.score_multiple_runs(test_runs, **score_kwargs)[0]
#      86 scores.append(mean_score)
#
# File ~/Code/ELPH-ML/incl/ELPH_NVAR.py:115, in SVDNVAR.train(self, rdim, n_VAR_steps, NVAR_p, intercept, standardize, method, **kwargs)
#     113 elif method == 'stlsq':
#     114     opt = STLSQ(**kwargs)
# --> 115     opt.fit(self.NVAR_state.T, self.target.T)
#     116     self.w = opt.coef_.T
#     117 else:
#
# File /usr/local/lib/python3.9/site-packages/pysindy/optimizers/base.py:170, in BaseOptimizer.fit(self, x_, y, sample_weight, **reduce_kws)
#     166     self.coef_ = self.initial_guess
#     168 self.history_ = [self.coef_]
# --> 170 self._reduce(x_normed, y, **reduce_kws)
#     171 self.ind_ = np.abs(self.coef_) > 1e-14
#     173 # Rescale coefficients to original units
#
# File /usr/local/lib/python3.9/site-packages/pysindy/optimizers/stlsq.py:198, in STLSQ._reduce(self, x, y)
#     193     warnings.warn(
#     194         "Sparsity parameter is too big ({}) and eliminated all "
#     195         "coefficients".format(self.threshold)
#     196     )
#     197     continue
# --> 198 coef_i = self._regress(x[:, ind[i]], y[:, i])
#     199 coef_i, ind_i = self._sparse_coefficients(
#     200     n_features, ind[i], coef_i, self.threshold
#     201 )
#     202 coef[i] = coef_i
#
# File /usr/local/lib/python3.9/site-packages/pysindy/optimizers/stlsq.py:139, in STLSQ._regress(self, x, y)
#     137 """Perform the ridge regression"""
#     138 kw = self.ridge_kw or {}
# --> 139 coef = ridge_regression(x, y, self.alpha, **kw)
#     140 self.iters += 1
#     141 return coef
#
# File /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:450, in ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, check_input)
#     304 def ridge_regression(
#     305     X,
#     306     y,
#    (...)
#     318     check_input=True,
#     319 ):
#     320     """Solve the ridge equation by the method of normal equations.
#     321
#     322     Read more in the :ref:`User Guide <ridge_regression>`.
#    (...)
#     448     This function won't compute the intercept.
#     449     """
# --> 450     return _ridge_regression(
#     451         X,
#     452         y,
#     453         alpha,
#     454         sample_weight=sample_weight,
#     455         solver=solver,
#     456         max_iter=max_iter,
#     457         tol=tol,
#     458         verbose=verbose,
#     459         positive=positive,
#     460         random_state=random_state,
#     461         return_n_iter=return_n_iter,
#     462         return_intercept=return_intercept,
#     463         X_scale=None,
#     464         X_offset=None,
#     465         check_input=check_input,
#     466     )
#
# File /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:598, in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input)
#     596 else:
#     597     try:
# --> 598         coef = _solve_cholesky(X, y, alpha)
#     599     except linalg.LinAlgError:
#     600         # use SVD solver if matrix is singular
#     601         solver = "svd"
#
# File /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:149, in _solve_cholesky(X, y, alpha)
#     146 n_features = X.shape[1]
#     147 n_targets = y.shape[1]
# --> 149 A = safe_sparse_dot(X.T, X, dense_output=True)
#     150 Xy = safe_sparse_dot(X.T, y, dense_output=True)
#     152 one_alpha = np.array_equal(alpha, len(alpha) * [alpha[0]])
#
# File /usr/local/lib/python3.9/site-packages/sklearn/utils/extmath.py:153, in safe_sparse_dot(a, b, dense_output)
#     151         ret = np.dot(a, b)
#     152 else:
# --> 153     ret = a @ b
#     155 if (
#     156     sparse.issparse(a)
#     157     and sparse.issparse(b)
#     158     and dense_output
#     159     and hasattr(ret, "toarray")
#     160 ):
#     161     return ret.toarray()
#
# KeyboardInterrupt:

# %%
def get_BayO_score(aExp):
    alpha = 10.0**aExp
    
    train_kwargs = {'alpha':alpha, 'rdim':20, 'n_VAR_steps':2, 'NVAR_p':2, 'method':'ridge', 'intercept':True, 'standardize':False}
    score_kwargs = {'norm':'fro', 'errSVD':False}
    
    m,s = ELPH_utils.get_KFold_CV_scores(NVAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
    return -1.*m - 1.*np.std(s)

# print(get_BayO_score(-3))

from bayes_opt import BayesianOptimization
# Bounded region of parameter space
pbounds = {'aExp': [-4, -1]}
optimizer = BayesianOptimization(f=get_BayO_score, pbounds=pbounds, random_state=817)

# optimizer.maximize(init_points=5, n_iter=60)

# %%
train_runs = runs[::1]
test_run = train_runs.pop(45)

NVAR.load_runs(train_runs)
NVAR.train(rdim=20, n_VAR_steps=2, NVAR_p=2, method='ridge', alpha=10.**-3.4, intercept=True, standardize=False)

NVAR.print_status()


print('NVAR err: ', NVAR.get_error(test_run, norm='fro') )
print('NVAR err compared to reconstruced run: ', NVAR.get_error(test_run, norm='fro', errSVD=True) )

preNVAR = NVAR.predict_single_run(test_run)
recon_runs = NVAR.Uhat @ NVAR.Uhat.T @ test_run


xmax = 100

plt.imshow(preNVAR, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('prediction')
plt.xlim(0,xmax)
plt.show()

plt.imshow(preNVAR-test_run, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('difference: pred - test')
plt.xlim(0,xmax)
plt.show()

plt.imshow(preNVAR-recon_runs, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('difference: pred - reconstructed test')
plt.xlim(0,xmax)
plt.show()

plt.imshow(preNVAR-recon_runs, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('difference: test - reconstructed test')
plt.xlim(0,xmax)
plt.show()
# Out:
# rdim:  20
# n_VAR_steps:  2
# NVAR_p:  2
# VAR state shape:  (40, 59202)
# NVAR state shape:  (861, 59202)
# target shape:  (20, 59202)
# weights shape:  (861, 20)
# NVAR err:  1.0028771155116418
# NVAR err compared to reconstruced run:  1.0005879804469848

# %%
train_kwargs = {'alpha':10**-1.0, 'rdim':20, 'n_VAR_steps':2, 'NVAR_p':2, 'method':'ridge', 'intercept':True, 'standardize':False}
score_kwargs = {'norm':'max', 'errSVD':True}

m,s = ELPH_utils.get_KFold_CV_scores(NVAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
print(m)
print(s)
# Out:
# /usr/local/lib/python3.9/site-packages/numpy/core/numeric.py:936: RuntimeWarning: overflow encountered in multiply
#   return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
# /Users/Stefan/Code/ELPH-ML/incl/ELPH_NVAR.py:142: RuntimeWarning: invalid value encountered in matmul
#   pred[:,j] = self.w.T @ NVAR_vec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [94], in <cell line: 4>()
#       1 train_kwargs = {'alpha':10**-1.0, 'rdim':20, 'n_VAR_steps':2, 'NVAR_p':2, 'method':'ridge', 'intercept':True, 'standardize':False}
#       2 score_kwargs = {'norm':'max', 'errSVD':True}
# ----> 4 m,s = ELPH_utils.get_KFold_CV_scores(NVAR, runs, folds=5, seed=817, score_kwargs=score_kwargs, train_kwargs=train_kwargs)
#       5 print(m)
#       6 print(s)
#
# File ~/Code/ELPH-ML/incl/ELPH_utils.py:84, in get_KFold_CV_scores(model, runs, folds, seed, score_kwargs, train_kwargs)
#      82     model.load_runs(train_runs)
#      83     model.train(**train_kwargs)
# ---> 84     mean_score = model.score_multiple_runs(test_runs, **score_kwargs)[0]
#      86     scores.append(mean_score)
#      88 return np.mean(scores), scores
#
# File ~/Code/ELPH-ML/incl/ELPH_VAR.py:132, in SVDVAR.score_multiple_runs(self, runs, **kwargs)
#     130 scores = []
#     131 for k in range(len(runs)):
# --> 132     scores.append(self.get_error(runs[k], **kwargs))
#     134 mean = np.mean(scores)
#     135 return mean, scores
#
# File ~/Code/ELPH-ML/incl/ELPH_VAR.py:106, in SVDVAR.get_error(self, run, pred, norm, errSVD)
#     104 def get_error(self, run, pred=np.zeros(1), norm='fro', errSVD = False):
#     105     if pred.size == 1:
# --> 106         pred = self.predict_single_run(run)
#     108     if errSVD == True:
#     109       run = self.Uhat @ self.Uhat.T @ run
#
# File ~/Code/ELPH-ML/incl/ELPH_NVAR.py:137, in SVDNVAR.predict_single_run(self, run)
#     134 for l in range(self.n_VAR_steps):
#     135     VARpredList.append( pred[:,j-self.n_VAR_steps+l] )
# --> 137 VAR_vec = np.concatenate( VARpredList, axis=0 )
#     138 NVAR_vec = self.build_VAR_p_Vec(VAR_vec, order=self.NVAR_p)
#     139 if self.intercept:
#
# KeyboardInterrupt:

# %%
from SVDAPPRX import SVDAPPRX

SVDapr = SVDAPPRX(runs)
SVDapr.train()

m,s = ELPH_utils.get_KFold_CV_scores(SVDapr, runs, folds=5, seed=817, train_kwargs={'rdim':20}, score_kwargs={ 'norm':'max'})
print(m)
print(s)
# Out:
# 0.00857206804478817
# [0.007781204726127177, 0.009120398395284472, 0.008432513577613359, 0.009107721286174854, 0.00841850223874099]

# %%
SVD_approx_err = np.zeros(n_kmax)
for rdim in range(n_kmax):
    SVD_approx_err[rdim] = ELPH_utils.get_KFold_CV_scores(SVDapr, runs, folds=5, seed=817, train_kwargs={'rdim':rdim+1}, score_kwargs={ 'norm':'max'})[0]

plt.grid()
plt.plot(np.arange(1,n_kmax+1),SVD_approx_err)
plt.xlabel('reconstruction rank')
plt.ylabel('reconstruction error')
plt.show()

plt.grid()
plt.semilogy(np.arange(1,n_kmax+1),SVD_approx_err)
plt.xlabel('reconstruction rank')
plt.ylabel('reconstruction error')
plt.ylim(1e-4,)
plt.show()
